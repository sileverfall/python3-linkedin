# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait

# %%
# options = ChromeOptions()
# options.add_argument('-incongnito')
# options.add_argument("--headless")
# options.add_argument(f'user-agent={headers}')
chromeDriverPath = "./"
browser = webdriver.Chrome(executable_path=chromeDriverPath + 'chromedriver_linux')

# %% [markdown]
# ## login

# %%
HOMEPAGE_URL = 'https://www.linkedin.com'

# %%
browser.get(HOMEPAGE_URL)

# %%
email = browser.find_element_by_css_selector('body > nav > section.sign-in-card.show > form > div.sign-in-form__inputs > div:nth-child(1) > input')

# %%
email.send_keys('tsb1071463@gmail.com')

# %%
pwd = browser.find_element_by_css_selector('body > nav > section.sign-in-card.show > form > div.sign-in-form__inputs > div:nth-child(2) > input')

# %%
pwd.send_keys('Alisa-0504')

# %%
pwd.send_keys(Keys.RETURN)

# %% [markdown]
# ## Company page

# %%
with open('./companies.txt','r') as f :
    a = f.read()

# %%
a = a.split('\n')

# %%
def get_companyDic(companyList):
    coms=list()
    for com in companyList:
        c = com.split(',')
        company = c[0]
        company_url = c[-1]
        try:
            browser.get(company_url)
            ta = browser.find_element_by_xpath("//*[contains(text(), 'See all ')]")
            out_com={
                'company':company,
                'company_url':company_url,
                'employee_size':ta.text.split(' ')[2],
                'employee_page':ta.get_attribute('href')
            }
            CompanyList = coms.append(out_com)
        except Exception as e:
            print(company)
            print(company_url)
            print(e)
    return CompanyList

# %%
# %time CompanyList = get_companyDic(a)
# Out:
# Verizon
# https://www.linkedin.com/company/1103/
# list index out of range
# UNDP
# https://www.linkedin.com/company/1861/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# International Flavors & Fragrances
# https://www.linkedin.com/company/5870/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# The Washington Post
# https://www.linkedin.com/company/166423/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# J. Walter Thompson Worldwide
# https://www.linkedin.com/company/2529/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Santander Bank
# https://www.linkedin.com/company/5705/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Leo Burnett
# https://www.linkedin.com/company/2970/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# BNY Mellon
# https://www.linkedin.com/company/162750/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# The Ritz-Carlton Hotel Company
# https://www.linkedin.com/company/214203/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Harvard University
# https://www.linkedin.com/company/1646/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Protiviti
# https://www.linkedin.com/company/3920/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Under Armour
# https://www.linkedin.com/company/14140/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Hyatt Hotels Corporation
# https://www.linkedin.com/company/220336/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# CNN BUSINESS
# https://www.linkedin.com/company/1747/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Genentech
# https://www.linkedin.com/company/2276/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Steelcase
# https://www.linkedin.com/company/166153/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Groupon
# https://www.linkedin.com/company/355611/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Bosch USA
# https://www.linkedin.com/company/165755/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Airbnb
# https://www.linkedin.com/company/309694/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# NASA - National Aeronautics and Space Administration
# https://www.linkedin.com/company/2003/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Liberty Mutual Insurance
# https://www.linkedin.com/company/2701/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Bill & Melinda Gates Foundation
# https://www.linkedin.com/company/8736/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Mercer
# https://www.linkedin.com/company/2423/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Covidien (Medtronic Minimally Invasive Therapies Group)
# https://www.linkedin.com/company/899089/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Alaska Airlines
# https://www.linkedin.com/company/162359/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# McCormick & Company
# https://www.linkedin.com/company/164888/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Allstate
# https://www.linkedin.com/company/1835/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# GM Financial
# https://www.linkedin.com/company/7466/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# IFC - International Finance Corporation
# https://www.linkedin.com/company/4783/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# U.S. Department of Homeland Security
# https://www.linkedin.com/company/2998/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# IDEO
# https://www.linkedin.com/company/164291/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Sony Music Entertainment
# https://www.linkedin.com/company/3039/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Citrix
# https://www.linkedin.com/company/2641/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# PNC
# https://www.linkedin.com/company/4167/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Hudson Global
# https://www.linkedin.com/company/2343/
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(text(), 'See all ')]"}
#   (Session info: chrome=76.0.3809.100)
#
# Amdocs
# https://www.linkedin.com/company/1539/
# Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=76.0.3809.100)
#
# Cushman & Wakefield
# https://www.linkedin.com/company/4060/
# Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=76.0.3809.100)
#
# Condé Nast
# https://www.linkedin.com/company/3308/
# Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=76.0.3809.100)
#
